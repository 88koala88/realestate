# %%
# 건축년도를 통해 몇년된 아파트 인지 컬럼 추가 (연식)
# 연식별 가격
# 법정동 별 가격
# 지역코드 에 따른 가격
# 층별 가격
# 월세, 전세 구분 컬럼
# 월세면 월세금액, 전세면 전세금액 파악

# %%
import pandas as pd
import os
import geopandas as gpd
import glob
import plotly.express as px
import plotly.graph_objects as go
import folium
import json
import math
import numpy as np
import json
import requests

os.chdir("/home/ubuntu/realestate")
print(os.getcwd())
# Out:
# /home/ubuntu/realestate

# %%
df = pd.read_csv("data/AptTrade_Total.csv")
df
# Out:
#          거래금액 거래유형  건축년도     년   법정동             아파트  월   일     전용면적 중개사소재지  \
# 0      100000       2007  2020   필운동     신동아블루아광화문의꿈  1   3  111.970
# 1      162000       2008  2020   사직동  광화문스페이스본(106동)  1   2  163.330
# 2       88000       1994  2020   내수동           세종로대우  1   6  109.910
# 3      130000       2004  2020   내수동            킹스매너  1   9  194.430
# 4      149000       2003  2020   내수동        경희궁파크팰리스  1  20  148.090
# ...       ...  ...   ...   ...   ...             ... ..  ..      ...    ...
# 58495   40500       1998  2020   평창동              삼성  1  18   59.970
# 58496   48850       1998  2020   평창동              삼성  1  28   84.980
# 58497   58990       2000  2020   무악동              현대  1  14   60.000
# 58498   79000       2000  2020   무악동              현대  1  18   60.000
# 58499  116500       2008  2020   무악동         인왕산아이파크  1  18   84.858
#
#            지번   지역코드   층 해제사유발생일 해제여부
# 0         254  11110   6
# 1         9-1  11110   2
# 2         167  11110  11
# 3      110-15  11110   4
# 4          95  11110   8
# ...       ...    ...  ..     ...  ...
# 58495     596  11110  10
# 58496     596  11110   3
# 58497      82  11110   1
# 58498      82  11110   3
# 58499      60  11110  11
#
# [58500 rows x 15 columns]

# %%
clean_df = df.drop(['거래유형','중개사소재지','해제사유발생일','해제여부'], axis=1)

# %%
clean_df
# Out:
#          거래금액  건축년도     년   법정동             아파트  월   일     전용면적      지번  \
# 0      100000  2007  2020   필운동     신동아블루아광화문의꿈  1   3  111.970     254
# 1      162000  2008  2020   사직동  광화문스페이스본(106동)  1   2  163.330     9-1
# 2       88000  1994  2020   내수동           세종로대우  1   6  109.910     167
# 3      130000  2004  2020   내수동            킹스매너  1   9  194.430  110-15
# 4      149000  2003  2020   내수동        경희궁파크팰리스  1  20  148.090      95
# ...       ...   ...   ...   ...             ... ..  ..      ...     ...
# 58495   40500  1998  2020   평창동              삼성  1  18   59.970     596
# 58496   48850  1998  2020   평창동              삼성  1  28   84.980     596
# 58497   58990  2000  2020   무악동              현대  1  14   60.000      82
# 58498   79000  2000  2020   무악동              현대  1  18   60.000      82
# 58499  116500  2008  2020   무악동         인왕산아이파크  1  18   84.858      60
#
#         지역코드   층
# 0      11110   6
# 1      11110   2
# 2      11110  11
# 3      11110   4
# 4      11110   8
# ...      ...  ..
# 58495  11110  10
# 58496  11110   3
# 58497  11110   1
# 58498  11110   3
# 58499  11110  11
#
# [58500 rows x 11 columns]
