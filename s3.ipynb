# %%
import os
import boto3
import glob

# apart-admin
AWS_ACCESS_KEY_ID = "AKIA3MUQWPZHZAME44OC"
AWS_ACCESS_KEY_SECRET = "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"

        
# set aws credentials 
s3r = boto3.resource('s3', aws_access_key_id=AWS_ACCESS_KEY_ID,
    aws_secret_access_key=AWS_ACCESS_KEY_SECRET)
bucket = s3r.Bucket('realestate-data-111')

dir_list = ['/home/ubuntu/realestate/data']
    
for i in range(len(dir_list)):
    directory = dir_list[i]
    
    path = dir_list[i] + "/**"
    file_list = glob.glob(path, recursive=True)

    for df in file_list:
        if '.' in df:
            to_df = df.replace("/home/ubuntu/realestate/", "")

            print(to_df)
            bucket.upload_file(df,to_df)
# Out:
# data/AptTrade/11545_202201.csv
# data/AptTrade/11470_202212.csv
# data/AptTrade/11500_202209.csv
# data/AptTrade/11170_202208.csv
# data/AptTrade/11140_202203.csv
# data/AptTrade/11290_202212.csv
# data/AptTrade/11200_202103.csv
# data/AptTrade/11320_202204.csv
# data/AptTrade/11590_202107.csv
# data/AptTrade/11710_202009.csv
# data/AptTrade/11110_202206.csv
# data/AptTrade/11260_202009.csv
# data/AptTrade/11440_202007.csv
# data/AptTrade/11215_202103.csv
# data/AptTrade/11620_202009.csv
# data/AptTrade/11530_202011.csv
# data/AptTrade/11410_202001.csv
# data/AptTrade/11740_202001.csv
# data/AptTrade/11740_202103.csv
# data/AptTrade/11410_202008.csv
# data/AptTrade/11710_202012.csv
# data/AptTrade/11680_202109.csv
# data/AptTrade/11590_202205.csv
# data/AptTrade/11350_202004.csv
# data/AptTrade/11305_202211.csv
# data/AptTrade/11650_202105.csv
# data/AptTrade/11440_202101.csv
# data/AptTrade/11260_202205.csv
# data/AptTrade/11740_202010.csv
# data/AptTrade/11260_202209.csv
# ...
